# %% [markdown]
# <a href="https://colab.research.google.com/github/26wh5a0538-create/NASSCOM/blob/main/week_Pandas_Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

print("--- Intermediate Pandas Exercise ---")
print("Complete each task by writing the requested Pandas code.")
print("------------------------------------")

print("\n--- Task 1: Basic Pandas Functions and Converting Arrays to DataFrames ---")

s1_1 = pd.Series([10, 20, 30, 40, 50])
print("\ns1_1:")
print(s1_1)

np_array1_2 = np.random.randint(1, 101, size=(3, 4))
print("\nnp_array1_2:")
print(np_array1_2)

df1_3 = pd.DataFrame(np_array1_2, columns=['A', 'B', 'C', 'D'])
print("\ndf1_3:")
print(df1_3)
# Out:
# --- Intermediate Pandas Exercise ---
# Complete each task by writing the requested Pandas code.
# ------------------------------------
#
# --- Task 1: Basic Pandas Functions and Converting Arrays to DataFrames ---
#
# s1_1:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64
#
# np_array1_2:
# [[41 50 16 54]
#  [25 84 69 71]
#  [61 62 20 40]]
#
# df1_3:
#     A   B   C   D
# 0  41  50  16  54
# 1  25  84  69  71
# 2  61  62  20  40

# %%
print("\n--- Task 2: Synthetic Data Generation for Practice ---")

np.random.seed(42)

dates = pd.date_range(start='2023-01-01', end='2023-04-09', periods=100)


df_sales = pd.DataFrame({
    'Date': dates,
    'Region': np.random.choice(['East', 'West', 'North', 'South'], size=100),
    'Product': np.random.choice(['Laptop', 'Mouse', 'Keyboard', 'Monitor'], size=100),
    'Sales': np.random.randint(100, 1001, size=100),
    'Quantity': np.random.randint(1, 11, size=100)
})

sales_nan_indices = np.random.choice(df_sales.index, size=5, replace=False)
df_sales.loc[sales_nan_indices, 'Sales'] = np.nan

quantity_nan_indices = np.random.choice(df_sales.index, size=3, replace=False)
df_sales.loc[quantity_nan_indices, 'Quantity'] = np.nan

print(df_sales)
# Out:
# --- Task 2: Synthetic Data Generation for Practice ---
#                             Date Region   Product  Sales  Quantity
# 0  2023-01-01 00:00:00.000000000  North  Keyboard  674.0       7.0
# 1  2023-01-01 23:45:27.272727272  South     Mouse  963.0       4.0
# 2  2023-01-02 23:30:54.545454545   East     Mouse    NaN       7.0
# 3  2023-01-03 23:16:21.818181818  North   Monitor  340.0       8.0
# 4  2023-01-04 23:01:49.090909090  North     Mouse  663.0       1.0
# ..                           ...    ...       ...    ...       ...
# 95 2023-04-05 00:58:10.909090910   West     Mouse  152.0       6.0
# 96 2023-04-06 00:43:38.181818182   West     Mouse  783.0       8.0
# 97 2023-04-07 00:29:05.454545455  South   Monitor  829.0       2.0
# 98 2023-04-08 00:14:32.727272728   West    Laptop  771.0       5.0
# 99 2023-04-09 00:00:00.000000000   East  Keyboard  809.0       1.0
#
# [100 rows x 5 columns]

# %%
print("\n--- Task 3: Indexing and Slicing in DataFrames ---")

df3_1 = df_sales[['Region', 'Sales']]
print("\ndf3_1:")
print(df3_1)

df3_2 = df_sales[df_sales['Product'] == 'Laptop']
print("\ndf3_2:")
print(df3_2)

df3_3 = df_sales[(df_sales['Region'] == 'East') & (df_sales['Sales'] > 500)]
print("\ndf3_3:")
print(df3_3)

monitor_rows = df_sales[df_sales['Product'] == 'Monitor']
val3_4 = df_sales.loc[monitor_rows.index[0], 'Sales']

print("\nval3_4:")
print(val3_4)
# Out:
# --- Task 3: Indexing and Slicing in DataFrames ---
#
# df3_1:
#    Region  Sales
# 0   North  674.0
# 1   South  963.0
# 2    East    NaN
# 3   North  340.0
# 4   North  663.0
# ..    ...    ...
# 95   West  152.0
# 96   West  783.0
# 97  South  829.0
# 98   West  771.0
# 99   East  809.0
#
# [100 rows x 2 columns]
#
# df3_2:
#                             Date Region Product  Sales  Quantity
# 16 2023-01-16 20:07:16.363636363  South  Laptop  624.0       4.0
# 19 2023-01-19 19:23:38.181818182  North  Laptop  798.0      10.0
# 21 2023-01-21 18:54:32.727272727   East  Laptop  185.0       3.0
# 24 2023-01-24 18:10:54.545454545  South  Laptop  781.0       4.0
# 27 2023-01-27 17:27:16.363636364   West  Laptop  745.0       8.0
# 31 2023-01-31 16:29:05.454545455   East  Laptop  655.0       1.0
# 32 2023-02-01 16:14:32.727272727  South  Laptop  439.0       9.0
# 33 2023-02-02 16:00:00.000000000   West  Laptop  897.0       9.0
# 35 2023-02-04 15:30:54.545454545   East  Laptop  739.0       7.0
# 36 2023-02-05 15:16:21.818181818  South  Laptop  605.0      10.0
# 37 2023-02-06 15:01:49.090909091   East  Laptop  447.0       3.0
# 39 2023-02-08 14:32:43.636363636  North  Laptop  330.0      10.0
# 41 2023-02-10 14:03:38.181818182  North  Laptop  324.0       4.0
# 48 2023-02-17 12:21:49.090909091   West  Laptop  358.0       9.0
# 52 2023-02-21 11:23:38.181818182  North  Laptop  510.0       3.0
# 54 2023-02-23 10:54:32.727272728  North  Laptop    NaN       8.0
# 58 2023-02-27 09:56:21.818181819  North  Laptop  333.0       8.0
# 61 2023-03-02 09:12:43.636363637  North  Laptop  926.0       8.0
# 65 2023-03-06 08:14:32.727272728   West  Laptop  571.0       4.0
# 71 2023-03-12 06:47:16.363636364   West  Laptop  541.0       2.0
# 78 2023-03-19 05:05:27.272727273  North  Laptop  212.0       4.0
# 80 2023-03-21 04:36:21.818181819  North  Laptop  724.0       5.0
# 84 2023-03-25 03:38:10.909090910  North  Laptop  101.0       7.0
# 85 2023-03-26 03:23:38.181818182  North  Laptop  741.0       3.0
# 92 2023-04-02 01:41:49.090909092   West  Laptop  502.0       6.0
# 98 2023-04-08 00:14:32.727272728   West  Laptop  771.0       5.0
#
# df3_3:
#                             Date Region   Product  Sales  Quantity
# 6  2023-01-06 22:32:43.636363636   East     Mouse  999.0       8.0
# 7  2023-01-07 22:18:10.909090909   East   Monitor  833.0       5.0
# 30 2023-01-30 16:43:38.181818182   East   Monitor  719.0       8.0
# 31 2023-01-31 16:29:05.454545455   East    Laptop  655.0       1.0
# 35 2023-02-04 15:30:54.545454545   East    Laptop  739.0       7.0
# 38 2023-02-07 14:47:16.363636364   East  Keyboard  572.0       7.0
# 57 2023-02-26 10:10:54.545454546   East     Mouse  918.0       1.0
# 59 2023-02-28 09:41:49.090909091   East   Monitor  783.0       4.0
# 63 2023-03-04 08:43:38.181818182   East   Monitor  771.0       6.0
# 67 2023-03-08 07:45:27.272727273   East  Keyboard  791.0       9.0
# 72 2023-03-13 06:32:43.636363637   East  Keyboard  663.0       2.0
# 74 2023-03-15 06:03:38.181818182   East   Monitor  609.0       NaN
# 82 2023-03-23 04:07:16.363636364   East     Mouse  798.0       8.0
# 87 2023-03-28 02:54:32.727272728   East  Keyboard  665.0       1.0
# 99 2023-04-09 00:00:00.000000000   East  Keyboard  809.0       1.0
#
# val3_4:
# 340.0

# %%
print("\n--- Task 4: Data Cleaning (Handling Missing Values) ---")

missing_counts4_1 = df_sales.isnull().sum()
print("Missing values:")
print(missing_counts4_1)

df4_2_filled = df_sales.copy()
df4_2_filled['Sales'] = df4_2_filled['Sales'].fillna(df4_2_filled['Sales'].mean())

df4_3_dropped = df_sales.dropna()

print("\nFilled DataFrame:")
print(df4_2_filled)

print("\nDataFrame after dropping missing values:")
print(df4_3_dropped)
# Out:
# --- Task 4: Data Cleaning (Handling Missing Values) ---
# Missing values:
# Date        0
# Region      0
# Product     0
# Sales       5
# Quantity    3
# dtype: int64
#
# Filled DataFrame:
#                             Date Region   Product       Sales  Quantity
# 0  2023-01-01 00:00:00.000000000  North  Keyboard  674.000000       7.0
# 1  2023-01-01 23:45:27.272727272  South     Mouse  963.000000       4.0
# 2  2023-01-02 23:30:54.545454545   East     Mouse  590.147368       7.0
# 3  2023-01-03 23:16:21.818181818  North   Monitor  340.000000       8.0
# 4  2023-01-04 23:01:49.090909090  North     Mouse  663.000000       1.0
# ..                           ...    ...       ...         ...       ...
# 95 2023-04-05 00:58:10.909090910   West     Mouse  152.000000       6.0
# 96 2023-04-06 00:43:38.181818182   West     Mouse  783.000000       8.0
# 97 2023-04-07 00:29:05.454545455  South   Monitor  829.000000       2.0
# 98 2023-04-08 00:14:32.727272728   West    Laptop  771.000000       5.0
# 99 2023-04-09 00:00:00.000000000   East  Keyboard  809.000000       1.0
#
# [100 rows x 5 columns]
#
# DataFrame after dropping missing values:
#                             Date Region   Product  Sales  Quantity
# 0  2023-01-01 00:00:00.000000000  North  Keyboard  674.0       7.0
# 1  2023-01-01 23:45:27.272727272  South     Mouse  963.0       4.0
# 3  2023-01-03 23:16:21.818181818  North   Monitor  340.0       8.0
# 4  2023-01-04 23:01:49.090909090  North     Mouse  663.0       1.0
# 5  2023-01-05 22:47:16.363636363  South     Mouse  195.0       6.0
# ..                           ...    ...       ...    ...       ...
# 95 2023-04-05 00:58:10.909090910   West     Mouse  152.0       6.0
# 96 2023-04-06 00:43:38.181818182   West     Mouse  783.0       8.0
# 97 2023-04-07 00:29:05.454545455  South   Monitor  829.0       2.0
# 98 2023-04-08 00:14:32.727272728   West    Laptop  771.0       5.0
# 99 2023-04-09 00:00:00.000000000   East  Keyboard  809.0       1.0
#
# [92 rows x 5 columns]

# %%
print("\n--- Task 5: Data Manipulation (Columns, Sorting, Grouping) ---")

df_sales['Total_Revenue'] = df_sales['Sales'] * df_sales['Quantity']

df5_2_sorted = df_sales.sort_values(by=['Date', 'Sales'], ascending=[True, False])

df5_3_grouped_region = df_sales.groupby('Region')[['Sales', 'Quantity']].sum()

df5_4_grouped_product = df_sales.groupby('Product')['Sales'].mean()

print("\nSorted DataFrame:")
print(df5_2_sorted)

print("\nGrouped by Region:")
print(df5_3_grouped_region)

print("\nAverage Sales by Product:")
print(df5_4_grouped_product)
# Out:
# --- Task 5: Data Manipulation (Columns, Sorting, Grouping) ---
#
# Sorted DataFrame:
#                             Date Region   Product  Sales  Quantity  \
# 0  2023-01-01 00:00:00.000000000  North  Keyboard  674.0       7.0
# 1  2023-01-01 23:45:27.272727272  South     Mouse  963.0       4.0
# 2  2023-01-02 23:30:54.545454545   East     Mouse    NaN       7.0
# 3  2023-01-03 23:16:21.818181818  North   Monitor  340.0       8.0
# 4  2023-01-04 23:01:49.090909090  North     Mouse  663.0       1.0
# ..                           ...    ...       ...    ...       ...
# 95 2023-04-05 00:58:10.909090910   West     Mouse  152.0       6.0
# 96 2023-04-06 00:43:38.181818182   West     Mouse  783.0       8.0
# 97 2023-04-07 00:29:05.454545455  South   Monitor  829.0       2.0
# 98 2023-04-08 00:14:32.727272728   West    Laptop  771.0       5.0
# 99 2023-04-09 00:00:00.000000000   East  Keyboard  809.0       1.0
#
#     Total_Revenue
# 0          4718.0
# 1          3852.0
# 2             NaN
# 3          2720.0
# 4           663.0
# ..            ...
# 95          912.0
# 96         6264.0
# 97         1658.0
# 98         3855.0
# 99          809.0
#
# [100 rows x 6 columns]
#
# Grouped by Region:
#           Sales  Quantity
# Region
# East    12564.0      88.0
# North   12585.0     140.0
# South   16136.0     133.0
# West    14779.0     133.0
#
# Average Sales by Product:
# Product
# Keyboard    593.066667
# Laptop      554.360000
# Monitor     561.380952
# Mouse       664.421053
# Name: Sales, dtype: float64
