# %% [markdown]
# <a href="https://colab.research.google.com/github/26wh5a0538-create/NASSCOM/blob/main/U6_%E2%80%94_Probability_%26_Statistics_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns

df = sns.load_dataset("titanic")

numerical_cols = df.select_dtypes(include="number").columns
categorical_cols = df.select_dtypes(include="object").columns

print("Numerical columns:")
print(list(numerical_cols))

print("\nCategorical columns:")
print(list(categorical_cols))
# Out:
# Numerical columns:
# ['survived', 'pclass', 'age', 'sibsp', 'parch', 'fare']
#
# Categorical columns:
# ['sex', 'embarked', 'who', 'embark_town', 'alive']

# %%
import pandas as pd
import seaborn as sns

df = sns.load_dataset("titanic")

mean_age = df["age"].mean()

print("Mean age:", mean_age)
# Out:
# Mean age: 29.69911764705882

# %%
import pandas as pd
import seaborn as sns

df = sns.load_dataset("titanic")

sex_counts = df["sex"].value_counts()

print("Value counts of sex:")
print(sex_counts)
# Out:
# Value counts of sex:
# sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt


df = sns.load_dataset("tips")

tip = df["tip"]

mean_tip = tip.mean()
median_tip = tip.median()
mode_tip = tip.mode()[0]

print("Mean:", mean_tip)
print("Median:", median_tip)
print("Mode:", mode_tip)

print("Mean > Median:", mean_tip > median_tip)

plt.hist(tip, bins=10, edgecolor="black")

plt.axvline(mean_tip, linestyle="--", label="Mean")
plt.axvline(median_tip, linestyle="-", label="Median")

plt.xlabel("Tip")
plt.ylabel("Frequency")
plt.title("Distribution of Tips")
plt.legend()
plt.show()
# Out:
# Mean: 2.99827868852459
# Median: 2.9
# Mode: 2.0
# Mean > Median: True

# %%
import seaborn as sns


df = sns.load_dataset("tips")

tip = df["tip"]

tip_range = tip.max() - tip.min()
tip_variance = tip.var()
tip_std = tip.std()

print("Range:", tip_range)
print("Variance:", tip_variance)
print("Standard deviation:", tip_std)

Q1 = tip.quantile(0.25)
Q3 = tip.quantile(0.75)
IQR = Q3 - Q1

print("Q1:", Q1)
print("Q3:", Q3)
print("IQR:", IQR)
print("Most robust measure of spread: IQR")
# Out:
# Range: 9.0
# Variance: 1.9144546380624725
# Standard deviation: 1.3836381890011826
# Q1: 2.0
# Q3: 3.5625
# IQR: 1.5625
# Most robust measure of spread: IQR

# %%
import seaborn as sns
import matplotlib.pyplot as plt

df = sns.load_dataset("tips")
tip = df["tip"]
y
five_number = {
    "Minimum": tip.min(),
    "Q1": tip.quantile(0.25),
    "Median": tip.median(),
    "Q3": tip.quantile(0.75),
    "Maximum": tip.max()
}

print("Five-number summary:")
print(five_number)

skewness = tip.skew()
print("\nSkewness:", skewness)

if skewness > 0:
    print("Comment: The data is positively skewed (leans to the right).")
elif skewness < 0:
    print("Comment: The data is negatively skewed (leans to the left).")
else:
    print("Comment: The data is approximately symmetric.")

# 3. Box plot of tip
plt.figure(figsize=(7, 4))
sns.boxplot(x=tip)

plt.title("Box Plot of Tips")
plt.xlabel("Tip")
plt.show()
# Out:
# Five-number summary:
# {'Minimum': 1.0, 'Q1': np.float64(2.0), 'Median': 2.9, 'Q3': np.float64(3.5625), 'Maximum': 10.0}
#
# Skewness: 1.4654510370979401
# Comment: The data is positively skewed (leans to the right).

# %%
import seaborn as sns
import matplotlib.pyplot as plt

df = sns.load_dataset("tips")

corr_matrix = df.select_dtypes(include="number").corr().round(2)

print("Correlation Matrix:")
print(corr_matrix)

plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", fmt=".2f")

plt.title("Correlation Heatmap")
plt.show()

print("\nDescriptive Statistics:")
print(df.describe()
# Out:
# Correlation Matrix:
#             total_bill   tip  size
# total_bill        1.00  0.68  0.60
# tip               0.68  1.00  0.49
# size              0.60  0.49  1.00
# Descriptive Statistics:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000
